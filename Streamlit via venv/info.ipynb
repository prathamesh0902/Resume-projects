# %%
import sys

print(sys.executable)
# Out:
# /workspaces/Resume-projects/Streamlit via venv/myvenv/bin/python

# %%
# !which python
# Out:
# /workspaces/Resume-projects/Streamlit via venv/myvenv/bin/python
